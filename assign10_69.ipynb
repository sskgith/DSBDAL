# %%
import pandas as pd
import seaborn as sns

# %%
flower=pd.read_csv('IRIS.csv')

# %%
print(flower)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.histplot(flower)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.boxplot(x='sepal_length',y='species',data=flower)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
sns.boxplot(x='petal_length',y='species',data=flower)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='species'>

# %%
sns.boxplot(x='sepal_width',y='species',data=flower)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='species'>

# %%
sns.boxplot(x='petal_width',y='species',data=flower)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='species'>

# %%
sns.histplot(x='sepal_length',hue='species',data=flower)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(x='petal_length',hue='species',data=flower)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(x='sepal_width',hue='species',data=flower)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(x='petal_width',hue='species',data=flower)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>
